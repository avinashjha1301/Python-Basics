# %% [markdown]
# 1 What is the difference between multithreading and multiprocessing?
#
# Difference between Multithreading and Multiprocessing:
#
# Multithreading allows a program to run multiple threads within the same process. These threads share the same memory space, which makes communication between them easy but can lead to data conflicts. It’s mainly used for I/O-bound tasks like reading files or handling network requests. However, in Python, the Global Interpreter Lock (GIL) prevents true parallel execution of threads.
#
# Multiprocessing, on the other hand, runs multiple independent processes, each with its own memory space. This allows true parallel execution and is ideal for CPU-bound tasks such as data analysis or complex computations. It avoids GIL limitations but uses more system memory.

# %% [markdown]
# 2. What are the challenges associated with memory management in Python?
#
# the main challenges of memory management in Python in concise pointers:
#
# Automatic Garbage Collection – Developers have limited control over when memory is freed.
#
# Reference Counting Overhead – Every object’s reference count is tracked, which adds processing overhead.
#
# Circular References – Objects referring to each other may not be cleaned up automatically.
#
# Memory Leaks – Unused objects may stay in memory due to lingering references.
#
# Fragmentation – Frequent memory allocation and deallocation can cause scattered free memory.
#
# Retention of Large Objects – Large data structures may hold memory even after deletion.
#
# Global Interpreter Lock (GIL) – Limits true parallelism, affecting memory usage efficiency.

# %%
'''Write a Python program that logs an error message to a log file when a division by zero exception occurs.'''
import logging
logging.basicConfig(filename='error.log', level=logging.ERROR, format='%(asctime)s - %(message)s')

try:
    a = 10
    b = 0
    result = a / b
except ZeroDivisionError as e:
    logging.error(f"Division by zero error occurred: {e}")

print("Program completed. Check 'error.log' for details.")
# Out:
# ERROR:root:Division by zero error occurred: division by zero
# Program completed. Check 'error.log' for details.

# %%
'''Write a Python program that reads from one file and writes its content to another file.'''
try:
    with open("source.txt", "r") as source_file:
        content = source_file.read()

    with open("destination.txt", "w") as dest_file:
        dest_file.write(content)

    print("File copied successfully!")

except FileNotFoundError:
    print("Source file not found!")
# Out:
# Source file not found!

# %%
'''Write a program that handles both IndexError and KeyError using a
try-except block.'''

try:
    numbers = [1, 2, 3]
    print(numbers[5])
    data = {"name": "Keshav"}
    print(data["age"])

except IndexError:
    print("IndexError: Tried to access an invalid list index.")
except KeyError:
    print("KeyError: Tried to access a non-existent key in a dictionary.")
# Out:
# IndexError: Tried to access an invalid list index.

# %% [markdown]
# What are the differences between NumPy arrays and Python lists?
#
# Data Type:
#
# List: Can store elements of different data types (e.g., int, float, string).
#
# NumPy Array: Stores elements of the same data type for efficiency.
#
# Performance:
#
# List: Slower for numerical operations.
#
# NumPy Array: Much faster due to optimized C-based implementation.
#
# Memory Usage:
#
# List: Consumes more memory.
#
# NumPy Array: Uses less memory because of fixed-type storage.
#
# Operations:
#
# List: Requires loops for element-wise operations.
#
# NumPy Array: Supports vectorized operations (e.g., a + b adds elements directly).
#
# Functionality:
#
# List: Limited built-in operations.
#
# NumPy Array: Provides advanced mathematical, statistical, and linear algebra functions.
#
# Dimensionality:
#
# List: Mostly 1D (though lists of lists can simulate 2D).
#
# NumPy Array: Supports multi-dimensional arrays (1D, 2D, 3D, etc.)

# %% [markdown]
# Explain the difference between apply() and map() in Pandas
#
# 🔹 map()
#
# Used with Series (single column).
#
# Applies a function, dictionary, or Series to each element of a Series.
#
# Works element-wise (on individual values).
#
# 🔹 apply()
#
# Used with both Series and DataFrame.
#
# Applies a function along an axis (rows or columns).
#
# Can work on entire rows or columns, not just individual elements.

# %%
'''Create a histogram using Seaborn to visualize a distribution.'''

import seaborn as sns
import matplotlib.pyplot as plt
data = [12, 15, 20, 21, 22, 25, 28, 30, 32, 35, 36, 37, 40, 42, 45]
sns.histplot(data, bins=8, kde=True, color='skyblue')

plt.title("Distribution of Values")
plt.xlabel("Value")
plt.ylabel("Frequency")

plt.show()

# %%
'''Use Pandas to load a CSV file and display its first 5 rows.'''

import pandas as pd

df = pd.read_csv('your_file.csv')

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3622320624.py in <cell line: 0>()
#       3 import pandas as pd
#       4
# ----> 5 df = pd.read_csv('your_file.csv')
#       6
#       7 print(df.head())
#
# ...

# %%
'''Calculate the correlation matrix using Seaborn and visualize it with a
heatmap.'''

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('your_file.csv')

corr_matrix = df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2464898966.py in <cell line: 0>()
#       6 import matplotlib.pyplot as plt
#       7
# ----> 8 df = pd.read_csv('your_file.csv')
#       9
#      10 corr_matrix = df.corr()
#
# ...
